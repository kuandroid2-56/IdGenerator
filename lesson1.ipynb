# %% [markdown]
# <a href="https://colab.research.google.com/github/kuandroid2-56/IdGenerator/blob/main/lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %% [markdown]
# *這是一個Ｈello課程*
